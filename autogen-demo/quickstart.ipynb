# %%
install autogen

# %%
pip install -U "autogen-agentchat" "autogen-ext[openai,azure]"
# Out:
# Collecting autogen-agentchat
#   Downloading autogen_agentchat-0.4.7-py3-none-any.whl.metadata (2.5 kB)
# Collecting autogen-ext[azure,openai]
#   Downloading autogen_ext-0.4.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting autogen-core==0.4.7 (from autogen-agentchat)
#   Downloading autogen_core-0.4.7-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonref~=1.1.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-core==0.4.7->autogen-agentchat) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-core==0.4.7->autogen-agentchat) (1.28.2)
# Collecting pillow>=11.0.0 (from autogen-core==0.4.7->autogen-agentchat)
#   Downloading pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting protobuf~=5.29.3 (from autogen-core==0.4.7->autogen-agentchat)
#   Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydantic<3.0.0,>=2.10.0 (from autogen-core==0.4.7->autogen-agentchat)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-core==0.4.7->autogen-agentchat) (4.12.2)
# Collecting azure-ai-inference>=1.0.0b7 (from autogen-ext[azure,openai])
#   Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting azure-core (from autogen-ext[azure,openai])
#   Downloading azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Collecting azure-identity (from autogen-ext[azure,openai])
#   Downloading azure_identity-1.20.0-py3-none-any.whl.metadata (81 kB)
# Requirement already satisfied: aiofiles in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (23.2.1)
# Requirement already satisfied: openai>=1.52.2 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (1.59.7)
# Requirement already satisfied: tiktoken>=0.8.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (0.8.0)
# Collecting isodate>=0.6.1 (from azure-ai-inference>=1.0.0b7->autogen-ext[azure,openai])
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,openai]) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,openai]) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (4.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (0.6.1)
# Requirement already satisfied: sniffio in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,openai]) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from tiktoken>=0.8.0->autogen-ext[azure,openai]) (2024.7.24)
# Requirement already satisfied: cryptography>=2.5 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,openai]) (44.0.0)
# Collecting msal>=1.30.0 (from azure-identity->autogen-ext[azure,openai])
#   Downloading msal-1.31.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->autogen-ext[azure,openai])
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: idna>=2.8 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.52.2->autogen-ext[azure,openai]) (3.8)
# Requirement already satisfied: cffi>=1.12 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (1.17.1)
# Requirement already satisfied: certifi in /Users/shuai.an/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,openai]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/shuai.an/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,openai]) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,openai]) (0.14.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->autogen-ext[azure,openai]) (2.10.1)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=1.2.0->azure-identity->autogen-ext[azure,openai])
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.4.7->autogen-agentchat) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.4.7->autogen-agentchat) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.7->autogen-agentchat) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.7->autogen-agentchat)
#   Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (2.2.2)
# Requirement already satisfied: pycparser in /Users/shuai.an/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->autogen-core==0.4.7->autogen-agentchat) (1.17.0)
# Requirement already satisfied: zipp>=0.5 in /Users/shuai.an/.venv/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.27.0->autogen-core==0.4.7->autogen-agentchat) (3.20.1)
# Downloading autogen_agentchat-0.4.7-py3-none-any.whl (66 kB)
# Downloading autogen_core-0.4.7-py3-none-any.whl (81 kB)
# Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
# Downloading autogen_ext-0.4.7-py3-none-any.whl (161 kB)
# Downloading azure_identity-1.20.0-py3-none-any.whl (188 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.31.1-py3-none-any.whl (113 kB)
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 3.7 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.2 MB/s eta 0:00:00a 0:00:01
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: pydantic-core, protobuf, portalocker, pillow, isodate, pydantic, azure-core, azure-ai-inference, autogen-core, msal, autogen-ext, autogen-agentchat, msal-extensions, azure-identity
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.0
#     Uninstalling protobuf-5.29.0:
#       Successfully uninstalled protobuf-5.29.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.4.0
#     Uninstalling pillow-10.4.0:
#       Successfully uninstalled pillow-10.4.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# Successfully installed autogen-agentchat-0.4.7 autogen-core-0.4.7 autogen-ext-0.4.7 azure-ai-inference-1.0.0b9 azure-core-1.32.0 azure-identity-1.20.0 isodate-0.7.2 msal-1.31.1 msal-extensions-1.2.0 pillow-11.1.0 portalocker-2.10.1 protobuf-5.29.3 pydantic-2.10.6 pydantic-core-2.27.2
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Run

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# Define a model client. You can use other model client that implements
# the `ChatCompletionClient` interface.
model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    base_url="https://use.52apikey.cn/v1",
    api_key="xxx",
)


# Define a simple function tool that the agent can use.
# For this example, we use a fake weather tool for demonstration purposes.
async def get_weather(city: str) -> str:
    """Get the weather for a given city."""
    return f"The weather in {city} is 73 degrees and Sunny."


# Define an AssistantAgent with the model, tool, system message, and reflection enabled.
# The system message instructs the agent via natural language.
agent = AssistantAgent(
    name="weather_agent",
    model_client=model_client,
    tools=[get_weather],
    system_message="You are a helpful assistant.",
    reflect_on_tool_use=True,
    model_client_stream=True,  # Enable streaming tokens from the model client.
)


# Run the agent and stream the messages to the console.
async def main() -> None:
    await Console(agent.run_stream(task="What is the weather in New York?"))


# NOTE: if running this inside a Python script you'll need to use asyncio.run(main()).
await main()
# Out:
# ---------- user ----------
# What is the weather in New York?
# ---------- weather_agent ----------
# [FunctionCall(id='01952775c01971f1ee985582d143650b', arguments='{"city": "New York"}', name='get_weather')]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in New York is 73 degrees and Sunny.', call_id='01952775c01971f1ee985582d143650b', is_error=False)]
# ---------- weather_agent ----------
# It's great to know that it's 73 degrees and sunny in New York. However, the weather there can change quite frequently. You might want to check a reliable weather forecasting website or app for the most up-to-date and detailed weather information in the coming hours and days.
